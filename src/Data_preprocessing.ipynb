# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('dataset/DTW_to_MIA.csv')

# %%
df.shape
# Out:
# (289413, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289413 entries, 0 to 289412
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         289413 non-null  int64
#  1   legId                              289413 non-null  object
#  2   searchDate                         289413 non-null  object
#  3   flightDate                         289413 non-null  object
#  4   startingAirport                    289413 non-null  object
#  5   destinationAirport                 289413 non-null  object
#  6   fareBasisCode                      289413 non-null  object
#  7   travelDuration                     289413 non-null  object
#  8   elapsedDays                        289413 non-null  int64
#  9   isBasicEconomy                     289413 non-null  bool
#  10  isRefundable                       289413 non-null  bool
#  11  isNonStop                          289413 non-null  bool
#  12  baseFare                           289413 non-null  float64
#  13  totalFare                          289413 non-null  float64
#  14  seatsRemaining                     289413 non-null  int64
#  15  totalTravelDistance                251271 non-null  float64
#  16  segmentsDepartureTimeEpochSeconds  289413 non-null  object
#  17  segmentsDepartureTimeRaw           289413 non-null  object
#  18  segmentsArrivalTimeEpochSeconds    289413 non-null  object
#  19  segmentsArrivalTimeRaw             289413 non-null  object
#  20  segmentsArrivalAirportCode         289413 non-null  object
#  21  segmentsDepartureAirportCode       289413 non-null  object
#  22  segmentsAirlineName                289413 non-null  object
#  23  segmentsAirlineCode                289413 non-null  object
#  24  segmentsEquipmentDescription       289038 non-null  object
#  25  segmentsDurationInSeconds          289413 non-null  object
#  26  segmentsDistance                   289413 non-null  object
#  27  segmentsCabinCode                  289413 non-null  object
# dtypes: bool(3), float64(3), int64(3), object(19)
# memory usage: 56.0+ MB

# %%
# only focus on nonstop flights and pick useful columns
df = df[df['isNonStop'] == True]
df = df.iloc[:,[2,3,7,8,9,10,12,14,15,17,19,22,24,27]]

# %%
# totalTravelDistance and isRefundable variables have no variance, so remove this column
print(df['totalTravelDistance'].value_counts())
print(df['isRefundable'].value_counts())
df.drop(['totalTravelDistance','isRefundable'], axis=1, inplace=True)
# Arrival time is decided by departure time and travel duration so it is redundant, remove it
df.drop(['segmentsArrivalTimeRaw'], axis=1, inplace=True)
# Drop first class cabin
df = df[df['segmentsCabinCode'] != 'first']
df.drop(['segmentsCabinCode'], axis=1, inplace=True)
# Out:
# 1153.0    23727
# Name: totalTravelDistance, dtype: int64
# False    40131
# Name: isRefundable, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40116 entries, 2 to 289412
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   searchDate                    40116 non-null  object
#  1   flightDate                    40116 non-null  object
#  2   travelDuration                40116 non-null  object
#  3   elapsedDays                   40116 non-null  int64
#  4   isBasicEconomy                40116 non-null  bool
#  5   baseFare                      40116 non-null  float64
#  6   seatsRemaining                40116 non-null  int64
#  7   segmentsDepartureTimeRaw      40116 non-null  object
#  8   segmentsAirlineName           40116 non-null  object
#  9   segmentsEquipmentDescription  39741 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# ## Deal with Missing Data

# %%
df.isna().sum()
# Out:
# searchDate                        0
# flightDate                        0
# travelDuration                    0
# elapsedDays                       0
# isBasicEconomy                    0
# baseFare                          0
# seatsRemaining                    0
# segmentsDepartureTimeRaw          0
# segmentsAirlineName               0
# segmentsEquipmentDescription    375
# dtype: int64

# %%
# remove the rows with missing values
df = df.dropna()

# %% [markdown]
# ## Change the Format of Some Variables

# %%
#travelDuration to hours
dates = []
for date in df['travelDuration'].values:
    if date[4:-1] != '':
        dates.append(int(date[2]) + round(float(date[4:-1])/60,1))
    else:
        dates.append(int(date[2]))
df['travelDuration'] = dates

# %%
# change flightDate to Date type
df['flightDate'] = pd.to_datetime(df['flightDate'])

# %%
# change searchDate to the days before flight days
df['searchDaysBeforeDepartue'] = (df['flightDate']-pd.to_datetime(df['searchDate'])).dt.days.astype(int)
df.drop(['searchDate'], axis=1, inplace=True)

# %%
# convert flightDate to the weekday 
df['flightDay'] = df['flightDate'].dt.day_name()
df.drop(['flightDate'], axis=1, inplace=True)

# %%
# change segmentsDepartureTimeRaw to four time categories
time_category = []
for date in df['segmentsDepartureTimeRaw'].values:
    time = int(date[11:13])
    if time >= 0 and time < 6:
        time_category.append('Night')
    elif time >= 6 and time < 12:
        time_category.append('Morning')
    elif time >=12 and time < 18:
        time_category.append('Afternoon')
    else:
        time_category.append('Evening')
df['departureTime'] = time_category
df.drop(['segmentsDepartureTimeRaw'], axis=1, inplace=True)

# %%
# rename some variables
df = df.rename(columns={"segmentsAirlineName": "airlineName", "segmentsEquipmentDescription": "equipmentDescription"})

# %%
df.head()
# Out:
#    travelDuration  elapsedDays  isBasicEconomy  baseFare  seatsRemaining  \
# 2             3.1            0           False    140.00               0
# 3             3.0            0           False    262.33               2
# 4             3.0            0           False    262.33               7
# 5             3.1            0           False    262.33               7
# 6             3.1            0           False    262.33               7
#
#          airlineName             equipmentDescription  \
# 2    Spirit Airlines  AIRBUS INDUSTRIE A321 SHARKLETS
# 3              Delta                   Boeing 737-900
# 4              Delta                      Airbus A321
# 5  American Airlines                      Embraer 175
# 6  American Airlines                   Boeing 737-800
#
#    searchDaysBeforeDepartue flightDay departureTime
# 2                         1    Sunday       Morning
# 3                         1    Sunday     Afternoon
# 4                         1    Sunday       Morning
# 5                         1    Sunday     Afternoon
# 6                         1    Sunday       Morning

# %%
df.shape
# Out:
# (39741, 10)

# %% [markdown]
# ## Drop Spirit Rows

# %%
df = df[~df.airlineName.str.match('Spirit')]

# %%
df.shape
# Out:
# (23846, 10)

# %%
# Drop elapsedDays column as it has no variance
df.drop(['elapsedDays'], axis=1, inplace=True)

# %% [markdown]
# ## Remove Outliers

# %%
# remove outliers in the response baseFare
from scipy import stats
df = df[(np.abs(stats.zscore(df['baseFare'])) < 3)]

# %%
df.shape
# Out:
# (23574, 9)

# %% [markdown]
# ## EDA

# %%
fig, axes = plt.subplots(5,2, figsize=(20,24))
sns.lineplot(ax=axes[0,0], x=df['searchDaysBeforeDepartue'], y=df['baseFare'])
sns.violinplot(ax=axes[0,1], y=df['flightDay'].astype('category'), x=df['baseFare'])
sns.lineplot(ax=axes[1,0], x=df['travelDuration'], y=df['baseFare'])
sns.violinplot(ax=axes[1,1], y=df['isBasicEconomy'].astype('category'), x=df['baseFare'])
sns.lineplot(ax=axes[2,0], x=df['seatsRemaining'].astype('category'), y=df['baseFare'])
sns.violinplot(ax=axes[2,1], y=df['departureTime'].astype('category'), x=df['baseFare'])
sns.violinplot(ax=axes[3,0], y=df['airlineName'], x=df['baseFare'])
sns.violinplot(ax=axes[3,1], y=df['equipmentDescription'], x=df['baseFare'])
sns.histplot(ax=axes[4,0], x=df['baseFare'], binwidth=50)
plt.savefig("EDA.png")
plt.show()

# %%
sns.lineplot(x=np.log(df['searchDaysBeforeDepartue']), y=df['baseFare'])
plt.show()

# %% [markdown]
# ## Variable Transformation and Simplification

# %%
# Transform searchDaysBeforeDeparture variable to log scale
df.loc[:,'searchDaysBeforeDepartue'] = round(np.log(df.loc[:,'searchDaysBeforeDepartue']),2)
df = df.rename(columns={'searchDaysBeforeDepartue': 'searchDaysBeforeDepartueLog'})

# %%
# For simplicity, combine some categories in the equipment description variable
df = df.replace(regex=r'Airbus A319', value=0)
df = df.replace(regex=r'^Embraer.*', value=0)
df = df.replace(regex=r'Airbus.*', value=1)
df = df.replace(regex=r'Boeing.*', value=1)

# %%
# Combine some categories in flightDay variable
df = df.replace({'flightDay': {'Monday':0, 'Tuesday':1, 'Wednesday':1, 'Thursday':0, 
                         'Friday':0, 'Saturday':0, 'Sunday':0}})

# %% [markdown]
# ## One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import csr_matrix
categorical_column = ['isBasicEconomy', 'airlineName', 'departureTime', 'equipmentDescription', 'flightDay']
enc = OneHotEncoder(drop='first')
df[categorical_column[:]] = csr_matrix.toarray(enc.fit_transform(df.loc[:,categorical_column[:]]))

# %%
df = df.rename(columns={'airlineName':'isDelta', 'departureTime':'isDepartureMorning', 
                        'equipmentDescription': 'isEquipmentOther','flightDay':'isFlightTueWed'})

# %%
df.head()
# Out:
#     travelDuration  isBasicEconomy  baseFare  seatsRemaining  isDelta  \
# 3              3.0             0.0    262.33               2      1.0
# 4              3.0             0.0    262.33               7      1.0
# 5              3.1             0.0    262.33               7      0.0
# 6              3.1             0.0    262.33               7      0.0
# 40             3.0             0.0    262.33               9      1.0
#
#     isEquipmentOther  searchDaysBeforeDepartueLog  isFlightTueWed  \
# 3                1.0                         0.00             0.0
# 4                1.0                         0.00             0.0
# 5                0.0                         0.00             0.0
# 6                1.0                         0.00             0.0
# 40               1.0                         0.69             0.0
#
#     isDepartureMorning
# 3                  0.0
# 4                  1.0
# 5                  0.0
# 6                  1.0
# 40                 0.0

# %%
df.describe()
# Out:
#        travelDuration  isBasicEconomy      baseFare  seatsRemaining  \
# count    23574.000000    23574.000000  23574.000000    23574.000000
# mean         3.022542        0.370620    200.546469        7.325910
# std          0.042481        0.482981     74.304410        2.237491
# min          3.000000        0.000000     68.840000        1.000000
# 25%          3.000000        0.000000    133.950000        7.000000
# 50%          3.000000        0.000000    199.070000        9.000000
# 75%          3.000000        1.000000    236.280000        9.000000
# max          3.200000        1.000000    468.840000       10.000000
#
#             isDelta  isEquipmentOther  searchDaysBeforeDepartueLog  \
# count  23574.000000      23574.000000                 23574.000000
# mean       0.646602          0.813651                     3.002053
# std        0.478035          0.389397                     0.912279
# min        0.000000          0.000000                     0.000000
# 25%        0.000000          1.000000                     2.560000
# 50%        1.000000          1.000000                     3.260000
# 75%        1.000000          1.000000                     3.690000
# max        1.000000          1.000000                     4.090000
#
#        isFlightTueWed  isDepartureMorning
# count    23574.000000        23574.000000
# mean         0.240816            0.704081
# std          0.427588            0.456465
# min          0.000000            0.000000
# 25%          0.000000            0.000000
# 50%          0.000000            1.000000
# 75%          0.000000            1.000000
# max          1.000000            1.000000

# %% [markdown]
# ## Check covariance

# %%
df.corr()
# Out:
#                              travelDuration  isBasicEconomy  baseFare  \
# travelDuration                     1.000000       -0.073703  0.152598
# isBasicEconomy                    -0.073703        1.000000 -0.649515
# baseFare                           0.152598       -0.649515  1.000000
# seatsRemaining                    -0.133528        0.475319 -0.348048
# isDelta                           -0.284942        0.335987 -0.132986
# isEquipmentOther                  -0.274843        0.367243 -0.250380
# searchDaysBeforeDepartueLog        0.000043        0.304701 -0.504803
# isFlightTueWed                    -0.037529        0.124068 -0.223396
# isDepartureMorning                -0.113427       -0.269493  0.159666
#
#                              seatsRemaining   isDelta  isEquipmentOther  \
# travelDuration                    -0.133528 -0.284942         -0.274843
# isBasicEconomy                     0.475319  0.335987          0.367243
# baseFare                          -0.348048 -0.132986         -0.250380
# seatsRemaining                     1.000000  0.357471          0.315005
# isDelta                            0.357471  1.000000          0.644376
# isEquipmentOther                   0.315005  0.644376          1.000000
# searchDaysBeforeDepartueLog        0.193916  0.008610          0.063004
# isFlightTueWed                     0.083085 -0.081721         -0.041299
# isDepartureMorning                -0.221983 -0.448563         -0.272547
#
#                              searchDaysBeforeDepartueLog  isFlightTueWed  \
# travelDuration                                  0.000043       -0.037529
# isBasicEconomy                                  0.304701        0.124068
# baseFare                                       -0.504803       -0.223396
# seatsRemaining                                  0.193916        0.083085
# isDelta                                         0.008610       -0.081721
# isEquipmentOther                                0.063004       -0.041299
# searchDaysBeforeDepartueLog                     1.000000       -0.011023
# isFlightTueWed                                 -0.011023        1.000000
# isDepartureMorning                              0.025956        0.166038
#
#                              isDepartureMorning
# travelDuration                        -0.113427
# isBasicEconomy                        -0.269493
# baseFare                               0.159666
# seatsRemaining                        -0.221983
# isDelta                               -0.448563
# isEquipmentOther                      -0.272547
# searchDaysBeforeDepartueLog            0.025956
# isFlightTueWed                         0.166038
# isDepartureMorning                     1.000000

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['baseFare'],axis=1)
y = df.loc[:,['baseFare']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=551)

# %%
X_train.to_csv('X_train.csv')
X_test.to_csv('X_test.csv')
y_train.to_csv('y_train.csv')
y_test.to_csv('y_test.csv')
